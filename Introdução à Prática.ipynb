# %%
import numpy as np

# %%
import numpy as np

vetor1 = [2.5, 5.4, 3.3, 2.5, 7.3]
vetor2 = [1.3, 3.4, 6.2, 8.7, 2.4]

v1 = np.array(vetor1)
v2 = np.array(vetor2)

res = 5*v1
vetor_soma = v1 + v2
prod_escalar = sum(v1*v2)

media = np.mean(v1)

print(np.full(10,3))
# Out:
# [3 3 3 3 3 3 3 3 3 3]

# %%
mat1 = [[2, 3, 1],
        [5, 4, 2],
        [7, 3, 1]]
mat2 = [[7, 1, 6],
        [5, 4, 3],
        [2, 7, 1]]

det = np.linalg.det(mat1)
mat_res = np.dot(mat1, mat2)
print(mat_res)
# Out:
# [[31 21 22]
#  [59 35 44]
#  [66 26 52]]

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 2*np.pi, 0.01)
y = np.sin(2*x)
plt.plot(x, y)

# %%
img = plt.imread('imgs/earth_gray.jpg')
plt.imshow(img, cmap = 'gray')

# %%
img_color = plt.imread('imgs/earth.jpg')
plt.imshow(img_color)

# %%
img_red = img_color[:,:, 0]
plt.imshow(img_red, cmap='Reds')
